# %%
#!usr/bin/env python3
import pandas as pd
from pathlib import Path
import praw
from tqdm.notebook import tqdm
import pandas as pd
import yfinance as yf
import re

# %%
reddit_df = pd.read_csv('10y_reddit_data.csv.zst', encoding='utf-8')
len(reddit_df)
# Out:
# /tmp/ipykernel_100825/335183901.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   reddit_df = pd.read_csv('10y_reddit_data.csv.zst', encoding='utf-8')

# %%
len(reddit_df)
# Out:
# 168791

# %%
stock_df = pd.read_csv('10y_stock_data.csv.zst')
len(stock_df)
# Out:
# 3653
